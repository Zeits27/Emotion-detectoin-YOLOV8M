# %%
import os
import shutil
import random
from glob import glob

# Dataset paths
dataset_path = "../data"
train_labels = os.path.join(dataset_path, "train", "labels")
train_images = os.path.join(dataset_path, "train", "images")
test_labels = os.path.join(dataset_path, "test", "labels")
test_images = os.path.join(dataset_path, "test", "images")

# Class index for "disgust"
# Check your data.yaml: ["angry", "disgust", "fear", ...] → disgust = 1
target_class = "1"

# Collect all train labels containing "disgust"
disgust_files = []
for label_path in glob(os.path.join(train_labels, "*.txt")):
    with open(label_path, "r") as f:
        lines = f.readlines()
    if any(line.startswith(target_class + " ") or line.strip() == target_class for line in lines):
        disgust_files.append(label_path)

# Shuffle and pick 15%
random.shuffle(disgust_files)
n_move = max(1, int(0.15 * len(disgust_files)))  # at least 1
files_to_move = disgust_files[:n_move]

print(f"Found {len(disgust_files)} 'disgust' samples in train. Moving {n_move} to test...")

# Move files
for label_path in files_to_move:
    base = os.path.splitext(os.path.basename(label_path))[0]

    # Move label
    dest_label = os.path.join(test_labels, os.path.basename(label_path))
    shutil.move(label_path, dest_label)

    # Move image (check extension)
    for ext in [".jpg", ".jpeg", ".png"]:
        img_path = os.path.join(train_images, base + ext)
        if os.path.exists(img_path):
            dest_img = os.path.join(test_images, os.path.basename(img_path))
            shutil.move(img_path, dest_img)
            print(f"Moved {img_path} → {dest_img}")
            break
# Out:
# Found 390 'disgust' samples in train. Moving 58 to test...
# Moved ../data/train/images/Training_89701855_jpg.rf.83d24f94f396d9fd311387ce7a1332d5.jpg → ../data/test/images/Training_89701855_jpg.rf.83d24f94f396d9fd311387ce7a1332d5.jpg
# Moved ../data/train/images/Training_53679453_jpg.rf.fe826563f144b11d047e933c0479f721.jpg → ../data/test/images/Training_53679453_jpg.rf.fe826563f144b11d047e933c0479f721.jpg
# Moved ../data/train/images/1_jpg.rf.e5777d37a413fbdd5c9bd6f5ed120d97.jpg → ../data/test/images/1_jpg.rf.e5777d37a413fbdd5c9bd6f5ed120d97.jpg
# Moved ../data/train/images/Training_62572176_jpg.rf.75197cb994176289ba373a11d6b67064.jpg → ../data/test/images/Training_62572176_jpg.rf.75197cb994176289ba373a11d6b67064.jpg
# Moved ../data/train/images/Training_65372676_jpg.rf.42f401a2b05d734050012b4dd83010b9.jpg → ../data/test/images/Training_65372676_jpg.rf.42f401a2b05d734050012b4dd83010b9.jpg
# Moved ../data/train/images/18_jpg.rf.92c9864e2065368a8dab4a2350b2349b.jpg → ../data/test/images/18_jpg.rf.92c9864e2065368a8dab4a2350b2349b.jpg
# Moved ../data/train/images/8_jpg.rf.62dd1236312914621318ade438d89243.jpg → ../data/test/images/8_jpg.rf.62dd1236312914621318ade438d89243.jpg
# Moved ../data/train/images/Training_8004276_jpg.rf.f97c148002e231b2ddc6f631e94b8961.jpg → ../data/test/images/Training_8004276_jpg.rf.f97c148002e231b2ddc6f631e94b8961.jpg
# Moved ../data/train/images/Training_52850336_jpg.rf.c05c76f266ea4d1238c1058312fa6726.jpg → ../data/test/images/Training_52850336_jpg.rf.c05c76f266ea4d1238c1058312fa6726.jpg
# Moved ../data/train/images/Training_8004276_jpg.rf.0b9e36b7762fe64459e0a5e527e8a62d.jpg → ../data/test/images/Training_8004276_jpg.rf.0b9e36b7762fe64459e0a5e527e8a62d.jpg
# Moved ../data/train/images/Training_32702370_jpg.rf.7dabdccd484a41f4fac648623d9217b6.jpg → ../data/test/images/Training_32702370_jpg.rf.7dabdccd484a41f4fac648623d9217b6.jpg
# Moved ../data/train/images/Training_69604773_jpg.rf.2d2ee211ebefad8f8f5ab61e0a632949.jpg → ../data/test/images/Training_69604773_jpg.rf.2d2ee211ebefad8f8f5ab61e0a632949.jpg
# Moved ../data/train/images/6_jpg.rf.a76cc01656bfef33513e42fcd856b521.jpg → ../data/test/images/6_jpg.rf.a76cc01656bfef33513e42fcd856b521.jpg
# Moved ../data/train/images/Training_63164084_jpg.rf.064b469c7a7b3061a0a0dc37b98ac39c.jpg → ../data/test/images/Training_63164084_jpg.rf.064b469c7a7b3061a0a0dc37b98ac39c.jpg
# Moved ../data/train/images/Training_73989844_jpg.rf.9a0b82e15355fa2233d3b9fd831eda21.jpg → ../data/test/images/Training_73989844_jpg.rf.9a0b82e15355fa2233d3b9fd831eda21.jpg
# Moved ../data/train/images/19_jpg.rf.02a40d6df07189dc2f7d3c97c29981d2.jpg → ../data/test/images/19_jpg.rf.02a40d6df07189dc2f7d3c97c29981d2.jpg
# Moved ../data/train/images/Training_71184114_jpg.rf.3173a02d55d3008b99541d6d9a92016f.jpg → ../data/test/images/Training_71184114_jpg.rf.3173a02d55d3008b99541d6d9a92016f.jpg
# Moved ../data/train/images/Training_59250682_jpg.rf.c672765713aab8f7550ebe0b073bdfa7.jpg → ../data/test/images/Training_59250682_jpg.rf.c672765713aab8f7550ebe0b073bdfa7.jpg
# Moved ../data/train/images/Training_76379398_jpg.rf.01825b5f7ac7feb18088d1bcfa32ee2f.jpg → ../data/test/images/Training_76379398_jpg.rf.01825b5f7ac7feb18088d1bcfa32ee2f.jpg
# Moved ../data/train/images/Training_56741392_jpg.rf.6367ec145b05127d43c00c03ac97d47b.jpg → ../data/test/images/Training_56741392_jpg.rf.6367ec145b05127d43c00c03ac97d47b.jpg
# Moved ../data/train/images/Training_31710630_jpg.rf.2f07439737309f482a710277996255d3.jpg → ../data/test/images/Training_31710630_jpg.rf.2f07439737309f482a710277996255d3.jpg
# Moved ../data/train/images/Training_55875804_jpg.rf.3a4219148c9cccaeb2db2f58efe17bd2.jpg → ../data/test/images/Training_55875804_jpg.rf.3a4219148c9cccaeb2db2f58efe17bd2.jpg
# Moved ../data/train/images/19_jpg.rf.c121e10339c8aeed759ba7075ec71e69.jpg → ../data/test/images/19_jpg.rf.c121e10339c8aeed759ba7075ec71e69.jpg
# Moved ../data/train/images/Training_87899581_jpg.rf.661aa572b40f3f258c5521e52552a177.jpg → ../data/test/images/Training_87899581_jpg.rf.661aa572b40f3f258c5521e52552a177.jpg
# Moved ../data/train/images/Training_58836036_jpg.rf.7e7376b2d5c97d527888e324c8dab712.jpg → ../data/test/images/Training_58836036_jpg.rf.7e7376b2d5c97d527888e324c8dab712.jpg
