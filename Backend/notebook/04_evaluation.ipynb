# %%
# =========================
# 03_evaluation.ipynb
# =========================

import os
import matplotlib.pyplot as plt
from ultralytics import YOLO
import seaborn as sns

# 1. Load model hasil training
model_path = "../weight/best5.pt"   # ganti sesuai lokasi
model = YOLO(model_path)

# 2. Evaluasi di validation/test set
results = model.val(
    data="Backend/data2/augmented/data.yaml",   # dataset config
    split="test",        # bisa 'val' atau 'test'

)
# Out:
# Ultralytics 8.3.192 🚀 Python-3.12.3 torch-2.8.0 CPU (Apple M1)
# Model summary (fused): 92 layers, 25,844,392 parameters, 0 gradients, 78.7 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 15
#      12 model = YOLO(model_path)
#      14 # 2. Evaluasi di validation/test set
# ---> 15 results = model.val(
#      16     data="Backend/data2/augmented/data.yaml",   # dataset config
#      17     split="test",        # bisa 'val' atau 'test'
#      18
#      19 )
#
# File ~/Dropbox/Mac/Documents/final project/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:635, in Model.val(self, validator, **kwargs)
#     632 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     634 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# ...

# %%
# 3. Print metrik utama
print("Precision:", results.results_dict['metrics/precision(B)'])
print("Recall:", results.results_dict['metrics/recall(B)'])
print("mAP50:", results.results_dict['metrics/mAP50(B)'])
print("mAP50-95:", results.results_dict['metrics/mAP50-95(B)'])
# Out:
# Precision: 0.7648848510367915
# Recall: 0.7958092950726795
# mAP50: 0.8153764029978657
# mAP50-95: 0.5987655666227543

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img_path = "runs/detect/val/confusion_matrix_normalized.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Confusion Matrix Normalized(YOLO output)")
plt.show()

img_path = "runs/detect/val/BoxF1_curve.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("F1 Box Curve(YOLO output)")
plt.show()

img_path = "runs/detect/val/BoxP_curve.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Box Precition Curve(YOLO output)")
plt.show()

img_path = "runs/detect/val/BoxPR_curve.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Box Precition Recall Curve(YOLO output)")
plt.show()

img_path = "runs/detect/val/BoxR_curve.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Box Recall Curve(YOLO output)")
plt.show()

# %%
# =========================
# 03_evaluation.ipynb
# =========================

import os
import matplotlib.pyplot as plt
from ultralytics import YOLO
import seaborn as sns

# 1. Load model hasil training
model_path = "../weight/best5.pt"   # ganti sesuai lokasi
model = YOLO(model_path)

# 2. Evaluasi di validation/test set
results = model.val(
    data="../data2/augmented/data.yaml",   # dataset config
    split="test",        # bisa 'val' atau 'test'

)
# Out:
# Ultralytics 8.3.192 🚀 Python-3.12.3 torch-2.8.0 CPU (Apple M1)
# Model summary (fused): 92 layers, 25,844,392 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.4 ms, read: 39.4±8.7 MB/s, size: 6.3 KB)
# val: Scanning /Users/nicholas/Dropbox/Mac/Documents/final project/Backend/data2/raw/test/labels... 941 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 941/941 3369.1it/s 0.3s0.2s
# val: New cache created: /Users/nicholas/Dropbox/Mac/Documents/final project/Backend/data2/raw/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 59/59 0.09it/s 11:3311.8s
#                    all        941        955      0.715      0.702      0.778      0.709
#                  anger        109        109      0.597      0.661      0.724      0.614
#                content        120        120      0.737      0.625      0.779      0.737
# ...

# %%
# 3. Print metrik utama
print("Precision:", results.results_dict['metrics/precision(B)'])
print("Recall:", results.results_dict['metrics/recall(B)'])
print("mAP50:", results.results_dict['metrics/mAP50(B)'])
print("mAP50-95:", results.results_dict['metrics/mAP50-95(B)'])
# Out:
# Precision: 0.715238635797192
# Recall: 0.7021094179040028
# mAP50: 0.7775832305021727
# mAP50-95: 0.7092157295884972

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img_path = "runs/detect/val17/confusion_matrix_normalized.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Confusion Matrix Normalized(YOLO output)")
plt.show()

img_path = "runs/detect/val17/BoxF1_curve.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("F1 Box Curve(YOLO output)")
plt.show()

img_path = "runs/detect/val17/BoxP_curve.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Box Precition Curve(YOLO output)")
plt.show()

img_path = "runs/detect/val17/BoxPR_curve.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Box Precition Recall Curve(YOLO output)")
plt.show()

img_path = "runs/detect/val17/BoxR_curve.png"

img = mpimg.imread(img_path)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Box Recall Curve(YOLO output)")
plt.show()

# %%
# =========================
# 03_evaluation.ipynb
# =========================

import os
import matplotlib.pyplot as plt
from ultralytics import YOLO
import seaborn as sns

# 1. Load model hasil training
model_path = "../weight/best4.pt"   # ganti sesuai lokasi
model = YOLO(model_path)

# 2. Evaluasi di validation/test set
results = model.val(
    data="../data2/data.yaml",   # dataset config
    split="val",        # bisa 'val' atau 'test'

)
# Out:
# Ultralytics 8.3.192 🚀 Python-3.12.3 torch-2.8.0 CPU (Apple M1)
# Model summary (fused): 72 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 52.3±17.5 MB/s, size: 6.7 KB)
# val: Scanning /Users/nicholas/Dropbox/Mac/Documents/final project/Backend/data2/valid/labels... 1873 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1873/1873 5177.7it/s 0.4s0.1s
# val: New cache created: /Users/nicholas/Dropbox/Mac/Documents/final project/Backend/data2/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 118/118 0.17it/s 11:415.5ss
#                    all       1873       1903      0.712      0.727      0.782      0.714
#                  anger        235        239      0.676      0.695      0.749      0.655
#                content        237        240      0.763      0.754      0.819      0.765
# ...

# %%
# 3. Print metrik utama
print("Precision:", results.results_dict['metrics/precision(B)'])
print("Recall:", results.results_dict['metrics/recall(B)'])
print("mAP50:", results.results_dict['metrics/mAP50(B)'])
print("mAP50-95:", results.results_dict['metrics/mAP50-95(B)'])
# Out:
# Precision: 0.712007256961872
# Recall: 0.7265902776303379
# mAP50: 0.7824464323511795
# mAP50-95: 0.7142933242571277
